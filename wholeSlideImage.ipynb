# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install imagecodecs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 MB 20.2 MB/s eta 0:00:00
# ...

# %%
#IMPORTS
from tifffile import imread, imwrite
from matplotlib import pyplot as plt

# %%
#Function to read the image
def readIMG(path):
  img = imread(path)
  return img

# %%
#function to print the original image
def printIMG(image):
  plt.imshow(image)

# %%
#Path to the WSI
wsi_path = "/content/drive/MyDrive/MSc/Research/useful_notebook/postPipelines/featureANDclassfication/CAEmodel1/TCGA-CR-6470-01A-01-TS1.a73d75fe-bd80-4dbb-a33b-54942d9b7057.svs"
wsi = readIMG(wsi_path)
printIMG(wsi)
